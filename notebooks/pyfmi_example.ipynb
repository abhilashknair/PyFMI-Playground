# %% [markdown]
# # PyFMI Examples

# %% [markdown]
# PyFMI comes with a range of different examples(see https://jmodelica.org/pyfmi/examples.html#) which can be a very useful source of information when implementing and solving your own problems. The examples are located at https://github.com/modelon-community/PyFMI/tree/master/src/pyfmi/examples.

# %%
from pyfmi.examples import *

fmi_bouncing_ball.run_demo()
